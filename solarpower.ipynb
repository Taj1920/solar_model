# %%
# pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/10.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/10.7 MB 280.2 kB/s eta 0:00:37
#    - -------------------------------------- 0.5/10.7 MB 280.2 kB/s eta 0:00:37
#    - -------------------------------------- 0.5/10.7 MB 280.2 kB/s eta 0:00:37
#    -- ------------------------------------- 0.8/10.7 MB 346.2 kB/s eta 0:00:29
#    -- ------------------------------------- 0.8/10.7 MB 346.2 kB/s eta 0:00:29
# ...

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix,accuracy_score,f1_score
from sklearn.preprocessing import OrdinalEncoder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       2 import pandas as pd
#       3 import pickle
# ----> 4 from sklearn.model_selection import train_test_split
#       5 from sklearn.ensemble import RandomForestClassifier
#       6 from sklearn.metrics import confusion_matrix,accuracy_score,f1_score
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
oe = OrdinalEncoder(categories=[['Low','Medium']])
df['Power_Level'] = oe.fit_transform(df[['Power_Level']])
df['Power_Level'] = df['Power_Level'].astype(int)

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,test_size=0.3,random_state=15)

# %%
model = RandomForestClassifier(n_estimators=100)
model.fit(Xtrain,ytrain)

# %%
print('Training eff: ',model.score(Xtrain,ytrain))
print('Testing eff: ',model.score(Xtest,ytest))
